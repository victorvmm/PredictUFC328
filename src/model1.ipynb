# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %run DataCleaning.ipynb

# %%
data = StricklandDS.iloc[:, 1:-1]
target = StricklandDS.iloc[:, -1]

test = ChimaevDS.iloc[0, 1:-1]
test
# Out:
# Age                    31
# Height                188
# Reach                 191
# Wins                   15
# Losses                  0
# SLpM                 4.04
# Str. Acc              0.6
# Str. Def             0.43
# SApM                 2.32
# TD Avg.              5.29
# TD Acc.              0.55
# TD Def.              0.85
# Sub avg.              1.8
# Belt                    0
# KO/TKO/Submission       0
# Time                  0.0
# Sig. Str.               0
# Sig. Str. B             0
# Sig. Str. %           0.0
# TD                      0
# TD %                  0.0
# CTRL                  0.0
# TD B                    0
# TD % B                0.0
# CTRL B                0.0
# Name: 0, dtype: object

# %%
model = LogisticRegression(penalty='l1', solver='liblinear', tol=1e-3, random_state=42)
model.fit(data, target)

pred = model.predict([test])
prob = model.predict_proba([test])
print(f'Previsão de Strickland vs Chimaev: {'derrota Strickland' if pred == [0] else 'vitoria Strickland'}')
# Out:
# c:\Users\vmm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\vmm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       2 model.fit(data, target)
#       4 pred = model.predict([test])
# ----> 5 prob = model.predict_proba([test])
#       6 print(f'Previsão de Strickland vs Chimaev: {'derrota Strickland' if pred == [0] else 'vitoria Strickland'}')
#
# File c:\Users\vmm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1431, in LogisticRegression.predict_proba(self, X)
#    1423 ovr = self.multi_class in ["ovr", "warn"] or (
#    1424     self.multi_class in ["auto", "deprecated"]
#    1425     and (
#    (...)   1428     )
#    1429 )
#    1430 if ovr:
# -> 1431     return super()._predict_proba_lr(X)
#    1432 else:
#    1433     decision = self.decision_function(X)
#
# File c:\Users\vmm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:398, in LinearClassifierMixin._predict_proba_lr(self, X)
#     391 """Probability estimation for OvR logistic regression.
#     392
#     393 Positive class probabilities are computed as
#     394 1. / (1. + np.exp(-self.decision_function(X)));
#     395 multiclass is handled by normalizing that over all classes.
#     396 """
#     397 prob = self.decision_function(X)
# --> 398 expit(prob, out=prob)
#     399 if prob.ndim == 1:
#     400     return np.vstack([1 - prob, prob]).T
#
# TypeError: ufunc 'expit' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
