# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %run DataCleaning.ipynb

# %%
data = StricklandDS.iloc[:, 1:-1]
target = StricklandDS.iloc[:, -1]

test = ChimaevDS.iloc[0, 1:-1]
data.dtypes
# Out:
# Age                  object
# Height               object
# Reach                object
# Wins                 object
# Losses               object
# SLpM                 object
# Str. Acc             object
# Str. Def             object
# SApM                 object
# TD Avg.              object
# TD Acc.              object
# TD Def.              object
# Sub avg.             object
# Belt                 object
# KO/TKO/Submission    object
# Time                 object
# Sig. Str.            object
# Sig. Str. B          object
# Sig. Str. %          object
# TD                   object
# TD %                 object
# CTRL                 object
# TD B                 object
# TD % B               object
# CTRL B               object
# dtype: object

# %%
model = LogisticRegression(penalty='l1', solver='liblinear', tol=1e-3, random_state=42)
model.fit(data, target)

pred = model.predict([test])
print(model.predict_proba([test]))
print(model.score(data,target))
# Out:
# /home/vmm/tf/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/vmm/tf/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       3
#       4 test = ChimaevDS.iloc[0, 1:-1]
#       5
#       6 model = LogisticRegression(penalty='l1', solver='liblinear', tol=1e-3, random_state=42)
# ----> 7 model.fit(data, target)
#       8
# ...
